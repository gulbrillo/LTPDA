# %% [markdown]
# # Compare LTPDA to pyda

# %%
import os
import sys

import numpy as np

import pyda

sys.path.insert(0, os.path.abspath('../'))

from pyda.tsdata import TSData
from pyda.fsdata import FSData
from pyda.dsp.spectral import psd
import numpy

FigSize = (15, 10)  # global setting for figure size

import matplotlib.pylab as pylab

params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (15, 10),
          'axes.labelsize': 'xx-large',
          'axes.titlesize': 'xx-large',
          'xtick.labelsize': 'xx-large',
          'ytick.labelsize': 'xx-large'}
pylab.rcParams.update(params)
# Out:
# WARNING:root:Version not known, importlib.metadata is not working correctly.

# %% [markdown]
# ## Load LTPDA time-series and Spectrum

# %%
ltpda_ts = TSData.from_txt_file('/Users/hewitson/Data/pyda/ltpda_ts.txt')
print(ltpda_ts)

ltpda_S_ts = FSData.from_txt_file('/Users/hewitson/Data/pyda/ltpda_S_ts.txt')
print(ltpda_S_ts)
# Out:
# Loading from /Users/hewitson/Data/pyda/ltpda_ts.txt...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ltpda_ts = TSData.from_txt_file('/Users/hewitson/Data/pyda/ltpda_ts.txt')
#       2 print(ltpda_ts)
#       4 ltpda_S_ts = FSData.from_txt_file('/Users/hewitson/Data/pyda/ltpda_S_ts.txt')
#
# File ~/working/pyda/pyda/tsdata.py:101, in TSData.from_txt_file(cls, filename)
#      97     raise Exception("Please specify a file to load from")
#      99 print("Loading from " + filename + "...")
# --> 101 x = numpy.loadtxt(filename, usecols=0)
#     102 y = numpy.loadtxt(filename, usecols=1)
#     104 obj = TSData(xaxis=x, yaxis=y, name=filename)
#
# ...

# %% [markdown]
# ## Compute PSD of ltpda time-series

# %%
S_ts = psd(ts=ltpda_ts, window='hanning', navs=100, percent_overlap=50, detrend_order=1)
print(S_ts)

# %%
ltpda_S_ts.loglog(S_ts)

# %%
print([S_ts.ydata(), ltpda_S_ts.ydata()])

# %%
s_ts = psd(ts=ltpda_ts, window='hanning', navs=100, percent_overlap=50, detrend_order=1, scale='ASD')
print(S_ts)

# %%
s_ts.loglog(S_ts.sqrt())

# %%
ts = TSData.randn(nsecs=1e4, fs=10)

# %%
S = psd(ts, navs=1)
print(S)
S2 =
S**2
